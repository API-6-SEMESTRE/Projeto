# %%
import pandas as pd
from mongo_portal import mongo_find_all, mongo_insert_one, mongo_insert_many

# Mostra as colunas e linhas da base header
header = mongo_find_all(db="cate", col="header_bronze")
df_header = pd.DataFrame(header)
print(f"linhas: {len(df_header.index)}")
df_header.head(5)
# Out:
# linhas: 18
#                         _id                   _idFile _lineNumber    contrato  \
# 0  62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3   108697000
# 1  630000d519f2f821f3915ac2  63000063e6282203617a4a1c           3   108697000
# 2  6301123e1fe6e2596566dd9a  630111a2b336dc5f51bee3b5           3   722764000
# 3  6302b525171b4e38d1b83f07  6302b4ad7d8f3341632e5b08           3  1198444000
# 4  6302c799809be80ea0bc1f83  6302b4adfc395e31428b925e           3  1197781000
#
#         dt_competencia numero_fatura  \
# 0  2022-08-14 21:00:00      43294838
# 1  2022-08-14 21:00:00      43294838
# 2  2022-08-19 21:00:00      43389083
# 3  2022-07-29 21:00:00      43066807
# 4  2022-07-29 21:00:00      43058991
#
#                                               _idLog  \
# 0  2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 1  2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 2  2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 3  2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 4  2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
#
#                    time_stamp
# 0  2022-10-07 22:59:24.957586
# 1  2022-10-07 22:59:24.957586
# 2  2022-10-07 22:59:24.957586
# 3  2022-10-07 22:59:24.957586
# 4  2022-10-07 22:59:24.957586

# %%
# Mostra os tipos de dados de cada coluna
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato          object
# dt_competencia    object
# numero_fatura     object
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Transforma o numero_fatura em número
df_header["numero_fatura"] = pd.to_numeric(df_header["numero_fatura"])
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato          object
# dt_competencia    object
# numero_fatura      int64
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_header.isnull().sum()
# Out:
# _id               0
# _idFile           0
# _lineNumber       0
# contrato          0
# dt_competencia    0
# numero_fatura     0
# _idLog            0
# time_stamp        0
# dtype: int64

# %%
# Mostra as colunas e linhas da base mensalidade
mensalidade = mongo_find_all(db="cate", col="mensalidade_bronze")
df_mensalidade = pd.DataFrame(mensalidade)
print(f"linhas: {len(df_mensalidade.index)}")
df_mensalidade.head(5)
# Out:
# linhas: 136
#                         _id                   _idFile  marca_otica  \
# 0  6340d993db49a655ee789071  62fffe3650790c092a7f8dcd    291305148
# 1  6340d993db49a655ee789072  62fffe3650790c092a7f8dcd    291441203
# 2  6340d993db49a655ee789073  62fffe3650790c092a7f8dcd    291469272
# 3  6340d993db49a655ee789074  63000063e6282203617a4a1c    291305148
# 4  6340d993db49a655ee789075  63000063e6282203617a4a1c    291441203
#
#                           nXmX_bXnXfiWiXriX                        plano  \
# 0                       MXRWXLLX WXNTXFXNTI  AMIL 700 QP NACIONAL R PJCA
# 1            JXIWX XRIWX DX XNDRXDX DX ILVX  AMIL 400 QP NACIONAL R PJCA
# 2  MXRIX BXNIGNX XLIVXIRX DX NXWIMXNTX JUWX  AMIL 400 QP NACIONAL R PJCA
# 3                       MXRWXLLX WXNTXFXNTI  AMIL 700 QP NACIONAL R PJCA
# 4            JXIWX XRIWX DX XNDRXDX DX ILVX  AMIL 400 QP NACIONAL R PJCA
#
#                                rubrica tp_beneficiario  valor_orig
# 0  Mens. Titular Faixa Etária Implant.               T     3892.76
# 1  Mens. Titular Faixa Etária Implant.               T     2834.42
# 2  Mens. Titular Faixa Etária Implant.               T     8525.43
# 3  Mens. Titular Faixa Etária Implant.               T     3892.76
# 4  Mens. Titular Faixa Etária Implant.               T     2834.42

# %%
df_mensalidade.dtypes
# Out:
# _id                   object
# _idFile               object
# marca_otica            int64
# nXmX_bXnXfiWiXriX     object
# plano                 object
# rubrica               object
# tp_beneficiario       object
# valor_orig           float64
# dtype: object

# %%
# Transforma algumas colunas em número
df_mensalidade["marca_otica"] = pd.to_numeric(df_mensalidade["marca_otica"])
df_mensalidade["valor_orig"] = pd.to_numeric(df_mensalidade["valor_orig"])
#df_mensalidade["outros"] = pd.to_numeric(df_mensalidade["outros"])
#df_mensalidade["outros_orig"] = pd.to_numeric(df_mensalidade["outros_orig"])
df_mensalidade.dtypes
# Out:
# _id                   object
# _idFile               object
# marca_otica            int64
# nXmX_bXnXfiWiXriX     object
# plano                 object
# rubrica               object
# tp_beneficiario       object
# valor_orig           float64
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_mensalidade.isnull().sum()
# Out:
# _id                  0
# _idFile              0
# marca_otica          0
# nXmX_bXnXfiWiXriX    0
# plano                0
# rubrica              0
# tp_beneficiario      0
# valor_orig           0
# dtype: int64

# %%
# Une as duas bases usando o _idFile
df_header_mensalidade = pd.merge(df_header, df_mensalidade, on="_idFile")
print(f"linhas: {len(df_header_mensalidade.index)}")
df_header_mensalidade.isnull().sum()
# Out:
# linhas: 136
# _id_x                0
# _idFile              0
# _lineNumber          0
# contrato             0
# dt_competencia       0
# numero_fatura        0
# _idLog               0
# time_stamp           0
# _id_y                0
# marca_otica          0
# nXmX_bXnXfiWiXriX    0
# plano                0
# rubrica              0
# tp_beneficiario      0
# valor_orig           0
# dtype: int64

# %%
# Mostra repetições
print(f"qtd de marca_otica contando repetições: {df_header_mensalidade['marca_otica'].value_counts().sum()}")
df_header_mensalidade["marca_otica"].value_counts()
# Out:
# qtd de marca_otica contando repetições: 136
# 291305148    3
# 291469272    3
# 291441203    3
# 76100372     2
# 131427024    2
#             ..
# 131444298    1
# 131444255    1
# 131341341    1
# 131341294    1
# 852308507    1
# Name: marca_otica, Length: 123, dtype: int64

# %%
# Transforma a marca_otica no index e remove suas repetições, deixando no mínimo 1 de cada
df_header_mensalidade_umarca = df_header_mensalidade.groupby("marca_otica").nth[0]
df_header_mensalidade_umarca.index.value_counts()
# Out:
# 73391747     1
# 131743767    1
# 131702254    1
# 131702114    1
# 131695479    1
#             ..
# 76100373     1
# 76100372     1
# 76100317     1
# 76100313     1
# 852308507    1
# Name: marca_otica, Length: 123, dtype: int64

# %%
# Mostra as colunas e qtd de linhas da base repasse
repasse = mongo_find_all(db="cate", col="repasse_bronze")
df_repasse = pd.DataFrame(repasse)
print(f"linhas: {len(df_repasse.index)}")
df_repasse.head(5)
# Out:
# linhas: 1080
#                         _id  cod_contrato  codigo_convenio  codigo_plano  \
# 0  6340d99edb49a655ee7890fa  1.189455e+09               19             0
# 1  6340d99edb49a655ee7890fb  1.189442e+09               57             0
# 2  6340d99edb49a655ee7890fc           NaN               19             0
# 3  6340d99edb49a655ee7890fd           NaN              278             0
# 4  6340d99edb49a655ee7890fe  1.189449e+09               19             0
#
#                 competencia  \
# 0  2022-08-04T21:00:00.000Z
# 1  2022-08-04T21:00:00.000Z
# 2  2022-08-04T21:00:00.000Z
# 3  2022-08-04T21:00:00.000Z
# 4  2022-08-04T21:00:00.000Z
#
#                                             convenio  dependente  \
# 0                                               FNEL           0
# 1                                              ANMEP           0
# 2                                               FNEL           0
# 3  SINDSIME -SINDICATO DOS EMPREENDEDORES INDIVID...           0
# 4                                               FNEL           0
#
#             dt_cancelamento               dt_situacao  \
# 0  2022-05-30T21:00:00.000Z  2022-05-30T21:00:00.000Z
# 1  2022-05-30T21:00:00.000Z  2022-05-30T21:00:00.000Z
# 2  2022-05-30T21:00:00.000Z  2022-05-30T21:00:00.000Z
# 3  2022-05-01T21:00:00.000Z  2022-05-01T21:00:00.000Z
# 4  2022-05-30T21:00:00.000Z  2022-05-30T21:00:00.000Z
#
#                dt_suspensao           inicio_vigencia  marca_otica  \
# 0  2022-05-30T21:00:00.000Z  2018-08-31T21:00:00.000Z     73473310
# 1  2022-04-28T21:00:00.000Z  2018-09-30T21:00:00.000Z     73711602
# 2  2022-05-30T21:00:00.000Z  2018-11-30T22:00:00.000Z     74224867
# 3                      None  2019-01-31T22:00:00.000Z     74640391
# 4  2022-05-30T21:00:00.000Z  2019-05-31T21:00:00.000Z     76213041
#
#                        nXmX_bXnXfXWXXrXX                     plano  \
# 0  RXFXXLLX GHXGNXNX FXGUXXRXDX WXRVXLHX      AMIL 400 QP NACIONAL
# 1                      LUXZ WXLX XQUXXRX           NEXT PLUS RM RJ
# 2          PXDRX HXNRXQUX FXRRXXRX WUNHX           NEXT PLUS RM RJ
# 3           FRXNWXWX XNDRXY WXRNX BRXTTX      AMIL 500 QP NACIONAL
# 4                  XLVXNX BXNFXM DX XLVX  NEXT MUNICIPAL SÃO PAULO
#
#    saude_net_orig situacao
# 0          923.24  INATIVO
# 1          868.74  INATIVO
# 2          254.60  INATIVO
# 3         1653.03  INATIVO
# 4          260.84  INATIVO

# %%
df_repasse.dtypes
# Out:
# _id                   object
# cod_contrato         float64
# codigo_convenio        int64
# codigo_plano           int64
# competencia           object
# convenio              object
# dependente             int64
# dt_cancelamento       object
# dt_situacao           object
# dt_suspensao          object
# inicio_vigencia       object
# marca_otica            int64
# nXmX_bXnXfXWXXrXX     object
# plano                 object
# saude_net_orig       float64
# situacao              object
# dtype: object

# %%
# Transforma algumas colunas em número
df_repasse["codigo_convenio"] = pd.to_numeric(df_repasse["codigo_convenio"])
df_repasse["codigo_plano"] = pd.to_numeric(df_repasse["codigo_plano"])
df_repasse["marca_otica"] = pd.to_numeric(df_repasse["marca_otica"])
#df_repasse["odonto"] = pd.to_numeric(df_repasse["odonto"])
#df_repasse["odonto_net"] = pd.to_numeric(df_repasse["odonto_net"])
#df_repasse["odonto_net_orig"] = pd.to_numeric(df_repasse["odonto_net_orig"])
#df_repasse["odonto_orig"] = pd.to_numeric(df_repasse["odonto_orig"])
df_repasse["saude_net_orig"] = pd.to_numeric(df_repasse["saude_net_orig"])
#df_repasse["saude_orig"] = pd.to_numeric(df_repasse["saude_orig"])
df_repasse["cod_contrato"] = df_repasse["cod_contrato"].astype(str)
df_repasse.dtypes
# Out:
# _id                   object
# cod_contrato          object
# codigo_convenio        int64
# codigo_plano           int64
# competencia           object
# convenio              object
# dependente             int64
# dt_cancelamento       object
# dt_situacao           object
# dt_suspensao          object
# inicio_vigencia       object
# marca_otica            int64
# nXmX_bXnXfXWXXrXX     object
# plano                 object
# saude_net_orig       float64
# situacao              object
# dtype: object

# %%
# Separa as linhas repetidas, mantendo pelo menos um registro das repetições
mask = df_repasse.marca_otica.duplicated()
print(f"Linhas repetidas: {len(df_repasse[mask])}")
print(f"Linhas únicas: {len(df_repasse[~mask])}")
df_repasse_u = df_repasse[~mask].copy()
# Out:
# Linhas repetidas: 534
# Linhas únicas: 546

# %%
# Analisa a coluna de contrato
df_repasse_u["cod_contrato"].value_counts()
# Out:
# nan             349
# 1189455000.0     43
# 1189426000.0     22
# 1189449000.0     13
# 108739000.0      10
# 1191011000.0     10
# 1189435000.0      8
# 0.0               8
# 310572000.0       7
# 326288000.0       6
# 927614000.0       5
# 1201671000.0      5
# 318048000.0       5
# 1191014000.0      5
# 927627000.0       4
# 927632000.0       4
# 1201881000.0      4
# 1189459000.0      4
# 1189442000.0      3
# 927616000.0       3
# 311084000.0       3
# 108697000.0       3
# 927223000.0       2
# 310603000.0       2
# 938494000.0       2
# 927630000.0       2
# 927264000.0       2
# 1189445000.0      2
# 336362000.0       2
# 310453000.0       2
# 320087000.0       1
# 1190477000.0      1
# 15033000.0        1
# 310450000.0       1
# 1189029000.0      1
# 326376000.0       1
# Name: cod_contrato, dtype: int64

# %%
# Remove as linhas sem contrato ou com valor 0
bd = "silver_anomalies"
dados_insuficientes = df_repasse_u[df_repasse_u.cod_contrato == "nan"]
dados_insuficientes.to_dict("records")
mongo_insert_many(dados_insuficientes.to_dict("records"), db=bd, col="dados_insuficientes")
dados_insuficientes = df_repasse_u[df_repasse_u.cod_contrato == "0.0"]
dados_insuficientes.to_dict("records")
mongo_insert_many(dados_insuficientes.to_dict("records"), db=bd, col="dados_insuficientes")
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "nan"]
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "0.0"]
print(f"linhas: {len(df_repasse_u.index)}")
df_repasse_u["cod_contrato"].value_counts()
# Out:
# linhas: 189
# 1189455000.0    43
# 1189426000.0    22
# 1189449000.0    13
# 1191011000.0    10
# 108739000.0     10
# 1189435000.0     8
# 310572000.0      7
# 326288000.0      6
# 927614000.0      5
# 318048000.0      5
# 1201671000.0     5
# 1191014000.0     5
# 927627000.0      4
# 1189459000.0     4
# 1201881000.0     4
# 927632000.0      4
# 311084000.0      3
# 927616000.0      3
# 1189442000.0     3
# 108697000.0      3
# 310603000.0      2
# 927223000.0      2
# 927630000.0      2
# 938494000.0      2
# 927264000.0      2
# 1189445000.0     2
# 336362000.0      2
# 310453000.0      2
# 1189029000.0     1
# 15033000.0       1
# 320087000.0      1
# 310450000.0      1
# 1190477000.0     1
# 326376000.0      1
# Name: cod_contrato, dtype: int64

# %%
# Verifica se a marca_otica do repasse está presente no cruzamento header_mensalidade
counter = 0
marcas_match = []
for marca_repasse in df_repasse_u["marca_otica"]:
    if marca_repasse in df_header_mensalidade_umarca.index:    # marca_otica presente na header_mensalidade
        counter += 1
        marcas_match.append(marca_repasse)
    else:    # marca_otica ausente da header_mensalidade
        mongo_insert_one(df_repasse_u.query(f"marca_otica == {marca_repasse}").to_dict("records")[0], db=bd, col="somente_repasse" )
print(marcas_match)
print(f"qtd de marca_otica que deu match: {counter}")
# Out:
# [291093370, 291139507, 78372767, 291214061, 291238688, 291263194, 291285783, 291305148, 291441203, 291469272, 291052304, 852199546, 852308507, 291191630, 84162731, 75018205]
# qtd de marca_otica que deu match: 16

# %%
# Deixa separado em um novo df apenas as linhas com marca_otica que deu match
match = df_repasse_u["marca_otica"].isin(marcas_match)
df_repasse_m = df_repasse_u.copy()[match]
df_repasse_m["marca_otica"].value_counts()
# Out:
# 291093370    1
# 291139507    1
# 78372767     1
# 291214061    1
# 291238688    1
# 291263194    1
# 291285783    1
# 291305148    1
# 291441203    1
# 291469272    1
# 291052304    1
# 852199546    1
# 852308507    1
# 291191630    1
# 84162731     1
# 75018205     1
# Name: marca_otica, dtype: int64

# %%
# Verifica os cod_contrato que estão presentes na base header_mensalidade
counter = 0
contrato_match = []
for contrato_repasse in df_repasse_m["cod_contrato"]:
    search = df_header_mensalidade[df_header_mensalidade["contrato"] == contrato_repasse[:-2]]
    if len(search.isnull().values) >= 1:
        contrato_match.append(contrato_repasse)
        counter += 1
    else:
        mongo_insert_one(df_repasse_m.query(f"cod_contrato == '{contrato_repasse}'").to_dict("records")[0], db=bd, col="somente_repasse")
print(contrato_match)
print(f"qtd de match: {counter}")
# Out:
# ['310572000.0', '310572000.0', '310572000.0', '310572000.0', '310572000.0', '310572000.0', '310572000.0', '108697000.0', '108697000.0', '108697000.0', '318048000.0', '311084000.0', '311084000.0', '318048000.0']
# qtd de match: 14

# %%
# Separa em um df apenas os matches de contrato
match = df_repasse_m["cod_contrato"].isin(contrato_match)
df_repasse_f = df_repasse_m.copy()[match]
df_repasse_f["cod_contrato"]
# Out:
# 19    310572000.0
# 20    310572000.0
# 21    310572000.0
# 22    310572000.0
# 23    310572000.0
# 24    310572000.0
# 25    310572000.0
# 26    108697000.0
# 28    108697000.0
# 29    108697000.0
# 33    318048000.0
# 35    311084000.0
# 37    311084000.0
# 38    318048000.0
# Name: cod_contrato, dtype: object

# %%
# Une as base header_mensalidade com a repasse
df_repasse_umarca = df_repasse_f.groupby("marca_otica").nth(0)
df_h_m_r = pd.merge(df_header_mensalidade_umarca, df_repasse_umarca, on="marca_otica")
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 78372767     630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291052304    630525e1e93b154dad93dba3  630520ea89a0eceb5649c1c7           3
# 291093370    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291139507    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291191630    630525e1e93b154dad93dba3  630520ea89a0eceb5649c1c7           3
# 291214061    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291238688    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291263194    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291285783    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291305148    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 291441203    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 291469272    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 852199546    630527e3bae0582dc78cfc3f  630520ea7e0aa107bbd349b9           3
# 852308507    630527e3bae0582dc78cfc3f  630520ea7e0aa107bbd349b9           3
#
#               contrato       dt_competencia  numero_fatura  \
# marca_otica
# 78372767     310572000  2022-08-14 21:00:00       43295208
# 291052304    318048000  2022-08-14 21:00:00       43295857
# 291093370    310572000  2022-08-14 21:00:00       43295208
# 291139507    310572000  2022-08-14 21:00:00       43295208
# 291191630    318048000  2022-08-14 21:00:00       43295857
# 291214061    310572000  2022-08-14 21:00:00       43295208
# 291238688    310572000  2022-08-14 21:00:00       43295208
# 291263194    310572000  2022-08-14 21:00:00       43295208
# 291285783    310572000  2022-08-14 21:00:00       43295208
# 291305148    108697000  2022-08-14 21:00:00       43294838
# 291441203    108697000  2022-08-14 21:00:00       43294838
# 291469272    108697000  2022-08-14 21:00:00       43294838
# 852199546    311084000  2022-08-14 21:00:00        1104591
# 852308507    311084000  2022-08-14 21:00:00        1104591
#
#                                                         _idLog  \
# marca_otica
# 78372767     2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291052304    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291093370    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291139507    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291191630    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291214061    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291238688    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291263194    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291285783    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291305148    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291441203    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291469272    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 852199546    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 852308507    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
#
#                              time_stamp                     _id_y  \
# marca_otica
# 78372767     2022-10-07 22:59:24.957586  6340d993db49a655ee7890df
# 291052304    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f0
# 291093370    2022-10-07 22:59:24.957586  6340d993db49a655ee7890dd
# 291139507    2022-10-07 22:59:24.957586  6340d993db49a655ee7890de
# 291191630    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f2
# 291214061    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e0
# 291238688    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e1
# 291263194    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e2
# 291285783    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e3
# 291305148    2022-10-07 22:59:24.957586  6340d993db49a655ee789071
# 291441203    2022-10-07 22:59:24.957586  6340d993db49a655ee789072
# 291469272    2022-10-07 22:59:24.957586  6340d993db49a655ee789073
# 852199546    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f7
# 852308507    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f8
#
#                                     nXmX_bXnXfiWiXriX  ...  \
# marca_otica                                            ...
# 78372767                      MXRIXNX BRXGXNWX MXRQUX  ...
# 291052304                XLINNY XLIWX XXVIXR DX PXIVX  ...
# 291093370                       NXTXLIX MXRXX MXDXIRX  ...
# 291139507                       XNX WXRXLINX BRXGXNWX  ...
# 291191630                          FXBIXNX FXNTX GXMX  ...
# 291214061                       UXLY FXRNXNDX DX LIMX  ...
# 291238688                            JXXB ILVX DX XUX  ...
# 291263194                     GLXUWX XUGUTX ILVX XNTX  ...
# 291285783                  XNXRLXNDX GXMX DX XLIVXIRX  ...
# 291305148                         MXRWXLLX WXNTXFXNTI  ...
# 291441203              JXIWX XRIWX DX XNDRXDX DX ILVX  ...
# 291469272    MXRIX BXNIGNX XLIVXIRX DX NXWIMXNTX JUWX  ...
# 852199546                  MXRWX VINIWIU RUBXM XGUIXR  ...
# 852308507             RIHXN MXRWXLX LUZ XRXUJX BXRBXX  ...
#
#                                                       convenio dependente  \
# marca_otica
# 78372767     GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          1
# 291052304    GP3 - UNEN/RN - UNIAO ESTUDANTIL DO NORTE E NO...          0
# 291093370    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291139507    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291191630    GP3 - UNEN/RN - UNIAO ESTUDANTIL DO NORTE E NO...          0
# 291214061    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291238688    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291263194    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291285783    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291305148    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291441203    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291469272    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 852199546    GP3 - UNEN/MA - UNIAO ESTUDANTIL DO NORTE E NO...          2
# 852308507    GP3 - UNEN/MA - UNIAO ESTUDANTIL DO NORTE E NO...          0
#
#                       dt_cancelamento               dt_situacao  \
# marca_otica
# 78372767                         None  2020-06-11T21:00:00.000Z
# 291052304                        None  2019-07-29T21:00:00.000Z
# 291093370    2022-07-28T21:00:00.000Z  2022-07-28T21:00:00.000Z
# 291139507                        None  2015-02-23T21:00:00.000Z
# 291191630                        None  2020-11-29T21:00:00.000Z
# 291214061    2022-07-17T21:00:00.000Z  2022-07-17T21:00:00.000Z
# 291238688                        None  2022-06-01T21:00:00.000Z
# 291263194                        None  2015-07-22T21:00:00.000Z
# 291285783                        None  2019-08-15T21:00:00.000Z
# 291305148                        None  2015-09-20T21:00:00.000Z
# 291441203    2022-07-25T21:00:00.000Z  2022-07-25T21:00:00.000Z
# 291469272                        None  2017-04-03T21:00:00.000Z
# 852199546                        None  2014-11-19T22:00:00.000Z
# 852308507                        None  2019-07-30T21:00:00.000Z
#
#                          dt_suspensao           inicio_vigencia  \
# marca_otica
# 78372767                         None  2020-06-11T21:00:00.000Z
# 291052304    2019-07-29T21:00:00.000Z  2014-10-31T22:00:00.000Z
# 291093370                        None  2014-12-31T22:00:00.000Z
# 291139507                        None  2015-02-28T21:00:00.000Z
# 291191630    2020-03-30T21:00:00.000Z  2015-04-30T21:00:00.000Z
# 291214061    2022-05-23T21:00:00.000Z  2015-05-31T21:00:00.000Z
# 291238688    2022-05-30T21:00:00.000Z  2015-06-30T21:00:00.000Z
# 291263194                        None  2015-07-31T21:00:00.000Z
# 291285783    2019-07-29T21:00:00.000Z  2015-08-31T21:00:00.000Z
# 291305148                        None  2015-09-30T21:00:00.000Z
# 291441203                        None  2016-03-31T21:00:00.000Z
# 291469272                        None  2016-04-30T21:00:00.000Z
# 852199546                        None  2014-11-30T22:00:00.000Z
# 852308507    2019-07-29T21:00:00.000Z  2015-01-31T22:00:00.000Z
#
#                                     nXmX_bXnXfXWXXrXX  \
# marca_otica
# 78372767                      MXRXXNX BRXGXNWX MXRQUX
# 291052304                XLXNNY XLXWX XXVXXR DX PXXVX
# 291093370                       NXTXLXX MXRXX MXDXXRX
# 291139507                       XNX WXRXLXNX BRXGXNWX
# 291191630                          FXBXXNX FXNTX GXMX
# 291214061                       UXLY FXRNXNDX DX LXMX
# 291238688                            JXXB XLVX DX XUX
# 291263194                     GLXUWX XUGUTX XLVX XNTX
# 291285783                  XNXRLXNDX GXMX DX XLXVXXRX
# 291305148                         MXRWXLLX WXNTXFXNTX
# 291441203              JXXWX XRXWX DX XNDRXDX DX XLVX
# 291469272    MXRXX BXNXGNX XLXVXXRX DX NXWXMXNTX JUWX
# 852199546                  MXRWX VXNXWXU RUBXM XGUXXR
# 852308507             RXHXN MXRWXLX LUZ XRXUJX BXRBXX
#
#                                        plano_y saude_net_orig situacao
# marca_otica
# 78372767                GP3 - BLUE PLUS 500 QP        1697.25    ATIVO
# 291052304               GP3 - BLUE PLUS 300 QC        1846.20    ATIVO
# 291093370               GP3 - BLUE PLUS 300 QC        1984.11  INATIVO
# 291139507               GP3 - BLUE PLUS 500 QP        2910.02    ATIVO
# 291191630               GP3 - BLUE PLUS 500 QP        1893.57    ATIVO
# 291214061               GP3 - BLUE PLUS 300 QC        3586.30  INATIVO
# 291238688               GP3 - BLUE PLUS 300 QC        2182.44    ATIVO
# 291263194               GP3 - BLUE PLUS 400 QP        3898.29    ATIVO
# 291285783               GP3 - BLUE PLUS 600 QP        5197.56    ATIVO
# 291305148    GP4 - AMIL 700 NACIONAL R PJCA QP        3892.76    ATIVO
# 291441203    GP4 - AMIL 400 NACIONAL R PJCA QP        2834.42  INATIVO
# 291469272    GP4 - AMIL 400 NACIONAL R PJCA QP        8525.43    ATIVO
# 852199546               GP3 - BLUE PLUS 300 QP        1498.64    ATIVO
# 852308507               GP3 - BLUE PLUS 300 QP        1498.64    ATIVO
#
# [14 rows x 29 columns]

# %%
# Verifica as linhas que estavam no header_mensalidade mas não estavam no repasse
counter = 0
marcas_lost = []
df = df_header_mensalidade_umarca.reset_index(level=0)
for i in df_header_mensalidade_umarca.index:
    if i not in df_h_m_r.index:
        mongo_insert_one(df.loc[counter].to_dict(), db=bd, col="somente_cliente")
        marcas_lost.append(i)
    counter +=1
print(marcas_lost)
print(f"qtd de linhas perdidas: {len(marcas_lost)}")
# Out:
# [73391747, 73394844, 73599828, 73611845, 73611877, 73611883, 73799319, 73811692, 74065782, 74065788, 74075133, 74081697, 74081768, 74090462, 74090463, 74090737, 74325051, 74543375, 74543416, 74766979, 74766980, 74766989, 74770467, 74773677, 74953220, 74953325, 74956673, 74958124, 75018205, 75187990, 75188813, 76090758, 76090759, 76100313, 76100317, 76100372, 76100373, 76100983, 76290913, 76662253, 76663439, 76663612, 76663637, 84162731, 131064185, 131064525, 131064614, 131065017, 131065050, 131065181, 131065190, 131065840, 131065858, 131065947, 131066081, 131066633, 131066641, 131066650, 131066749, 131160249, 131160346, 131160354, 131160371, 131160401, 131160427, 131160435, 131160451, 131172476, 131226649, 131226746, 131227360, 131236822, 131285637, 131311786, 131341294, 131341341, 131419021, 131427024, 131444255, 131444298, 131563190, 131570927, 131572598, 131607031, 131616978, 131648594, 131695436, 131695479, 131702114, 131702254, 131738020, 131743767, 131744241, 131756117, 133301630, 290951119, 291026931, 291111408, 291139515, 291214070, 291305555, 291396003, 291417728, 291469310, 291486169, 291503802, 291554270, 851831940, 852199538]
# qtd de linhas perdidas: 109

# %%
# Analisa se o contrato da match, afinal eles são os campos chave entre header e repasse
# Salva num dict alguns dados relevantes sobre essa anomalia
contrato_unmatch = {"header_mensalidade": [], "repasse": [], "tp_beneficiario": [], "marca_otica": [], "rubrica": []}
for i in df_h_m_r.index:    # contrato vem do header_mensalidade e cod_contrato do repasse
    if df_h_m_r["contrato"].at[i] != df_h_m_r["cod_contrato"].at[i][:-2]:
        contrato_unmatch["header_mensalidade"].append(df_h_m_r["contrato"].at[i])
        contrato_unmatch["repasse"].append(df_h_m_r["cod_contrato"].at[i][:-2])
        contrato_unmatch["tp_beneficiario"].append(df_h_m_r["tp_beneficiario"].at[i])
        contrato_unmatch["marca_otica"].append(i)
        contrato_unmatch["rubrica"].append(df_h_m_r["rubrica"].at[i])
        mongo_insert_one(df_h_m_r.loc[i].to_dict(), db=bd, col="dados_inconsistentes")
        df_h_m_r.drop(i, inplace=True)
contrato_unmatch
# Out:
# {'header_mensalidade': [],
#  'repasse': [],
#  'tp_beneficiario': [],
#  'marca_otica': [],
#  'rubrica': []}

# %%
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 78372767     630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291052304    630525e1e93b154dad93dba3  630520ea89a0eceb5649c1c7           3
# 291093370    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291139507    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291191630    630525e1e93b154dad93dba3  630520ea89a0eceb5649c1c7           3
# 291214061    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291238688    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291263194    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291285783    630521951e74c614e130cd93  630520e93299fb8245e2ee5d           3
# 291305148    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 291441203    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 291469272    62fffee77c45476c4844c3a7  62fffe3650790c092a7f8dcd           3
# 852199546    630527e3bae0582dc78cfc3f  630520ea7e0aa107bbd349b9           3
# 852308507    630527e3bae0582dc78cfc3f  630520ea7e0aa107bbd349b9           3
#
#               contrato       dt_competencia  numero_fatura  \
# marca_otica
# 78372767     310572000  2022-08-14 21:00:00       43295208
# 291052304    318048000  2022-08-14 21:00:00       43295857
# 291093370    310572000  2022-08-14 21:00:00       43295208
# 291139507    310572000  2022-08-14 21:00:00       43295208
# 291191630    318048000  2022-08-14 21:00:00       43295857
# 291214061    310572000  2022-08-14 21:00:00       43295208
# 291238688    310572000  2022-08-14 21:00:00       43295208
# 291263194    310572000  2022-08-14 21:00:00       43295208
# 291285783    310572000  2022-08-14 21:00:00       43295208
# 291305148    108697000  2022-08-14 21:00:00       43294838
# 291441203    108697000  2022-08-14 21:00:00       43294838
# 291469272    108697000  2022-08-14 21:00:00       43294838
# 852199546    311084000  2022-08-14 21:00:00        1104591
# 852308507    311084000  2022-08-14 21:00:00        1104591
#
#                                                         _idLog  \
# marca_otica
# 78372767     2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291052304    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291093370    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291139507    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291191630    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291214061    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291238688    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291263194    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291285783    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291305148    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291441203    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 291469272    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 852199546    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
# 852308507    2022-10-07_22-59-24.721585_d56ac0ec-46ac-11ed-...
#
#                              time_stamp                     _id_y  \
# marca_otica
# 78372767     2022-10-07 22:59:24.957586  6340d993db49a655ee7890df
# 291052304    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f0
# 291093370    2022-10-07 22:59:24.957586  6340d993db49a655ee7890dd
# 291139507    2022-10-07 22:59:24.957586  6340d993db49a655ee7890de
# 291191630    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f2
# 291214061    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e0
# 291238688    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e1
# 291263194    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e2
# 291285783    2022-10-07 22:59:24.957586  6340d993db49a655ee7890e3
# 291305148    2022-10-07 22:59:24.957586  6340d993db49a655ee789071
# 291441203    2022-10-07 22:59:24.957586  6340d993db49a655ee789072
# 291469272    2022-10-07 22:59:24.957586  6340d993db49a655ee789073
# 852199546    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f7
# 852308507    2022-10-07 22:59:24.957586  6340d993db49a655ee7890f8
#
#                                     nXmX_bXnXfiWiXriX  ...  \
# marca_otica                                            ...
# 78372767                      MXRIXNX BRXGXNWX MXRQUX  ...
# 291052304                XLINNY XLIWX XXVIXR DX PXIVX  ...
# 291093370                       NXTXLIX MXRXX MXDXIRX  ...
# 291139507                       XNX WXRXLINX BRXGXNWX  ...
# 291191630                          FXBIXNX FXNTX GXMX  ...
# 291214061                       UXLY FXRNXNDX DX LIMX  ...
# 291238688                            JXXB ILVX DX XUX  ...
# 291263194                     GLXUWX XUGUTX ILVX XNTX  ...
# 291285783                  XNXRLXNDX GXMX DX XLIVXIRX  ...
# 291305148                         MXRWXLLX WXNTXFXNTI  ...
# 291441203              JXIWX XRIWX DX XNDRXDX DX ILVX  ...
# 291469272    MXRIX BXNIGNX XLIVXIRX DX NXWIMXNTX JUWX  ...
# 852199546                  MXRWX VINIWIU RUBXM XGUIXR  ...
# 852308507             RIHXN MXRWXLX LUZ XRXUJX BXRBXX  ...
#
#                                                       convenio dependente  \
# marca_otica
# 78372767     GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          1
# 291052304    GP3 - UNEN/RN - UNIAO ESTUDANTIL DO NORTE E NO...          0
# 291093370    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291139507    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291191630    GP3 - UNEN/RN - UNIAO ESTUDANTIL DO NORTE E NO...          0
# 291214061    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291238688    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291263194    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291285783    GP3 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291305148    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291441203    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 291469272    GP4 - FACERN - FEDERACAO DAS ASSOCIACOES COMER...          0
# 852199546    GP3 - UNEN/MA - UNIAO ESTUDANTIL DO NORTE E NO...          2
# 852308507    GP3 - UNEN/MA - UNIAO ESTUDANTIL DO NORTE E NO...          0
#
#                       dt_cancelamento               dt_situacao  \
# marca_otica
# 78372767                         None  2020-06-11T21:00:00.000Z
# 291052304                        None  2019-07-29T21:00:00.000Z
# 291093370    2022-07-28T21:00:00.000Z  2022-07-28T21:00:00.000Z
# 291139507                        None  2015-02-23T21:00:00.000Z
# 291191630                        None  2020-11-29T21:00:00.000Z
# 291214061    2022-07-17T21:00:00.000Z  2022-07-17T21:00:00.000Z
# 291238688                        None  2022-06-01T21:00:00.000Z
# 291263194                        None  2015-07-22T21:00:00.000Z
# 291285783                        None  2019-08-15T21:00:00.000Z
# 291305148                        None  2015-09-20T21:00:00.000Z
# 291441203    2022-07-25T21:00:00.000Z  2022-07-25T21:00:00.000Z
# 291469272                        None  2017-04-03T21:00:00.000Z
# 852199546                        None  2014-11-19T22:00:00.000Z
# 852308507                        None  2019-07-30T21:00:00.000Z
#
#                          dt_suspensao           inicio_vigencia  \
# marca_otica
# 78372767                         None  2020-06-11T21:00:00.000Z
# 291052304    2019-07-29T21:00:00.000Z  2014-10-31T22:00:00.000Z
# 291093370                        None  2014-12-31T22:00:00.000Z
# 291139507                        None  2015-02-28T21:00:00.000Z
# 291191630    2020-03-30T21:00:00.000Z  2015-04-30T21:00:00.000Z
# 291214061    2022-05-23T21:00:00.000Z  2015-05-31T21:00:00.000Z
# 291238688    2022-05-30T21:00:00.000Z  2015-06-30T21:00:00.000Z
# 291263194                        None  2015-07-31T21:00:00.000Z
# 291285783    2019-07-29T21:00:00.000Z  2015-08-31T21:00:00.000Z
# 291305148                        None  2015-09-30T21:00:00.000Z
# 291441203                        None  2016-03-31T21:00:00.000Z
# 291469272                        None  2016-04-30T21:00:00.000Z
# 852199546                        None  2014-11-30T22:00:00.000Z
# 852308507    2019-07-29T21:00:00.000Z  2015-01-31T22:00:00.000Z
#
#                                     nXmX_bXnXfXWXXrXX  \
# marca_otica
# 78372767                      MXRXXNX BRXGXNWX MXRQUX
# 291052304                XLXNNY XLXWX XXVXXR DX PXXVX
# 291093370                       NXTXLXX MXRXX MXDXXRX
# 291139507                       XNX WXRXLXNX BRXGXNWX
# 291191630                          FXBXXNX FXNTX GXMX
# 291214061                       UXLY FXRNXNDX DX LXMX
# 291238688                            JXXB XLVX DX XUX
# 291263194                     GLXUWX XUGUTX XLVX XNTX
# 291285783                  XNXRLXNDX GXMX DX XLXVXXRX
# 291305148                         MXRWXLLX WXNTXFXNTX
# 291441203              JXXWX XRXWX DX XNDRXDX DX XLVX
# 291469272    MXRXX BXNXGNX XLXVXXRX DX NXWXMXNTX JUWX
# 852199546                  MXRWX VXNXWXU RUBXM XGUXXR
# 852308507             RXHXN MXRWXLX LUZ XRXUJX BXRBXX
#
#                                        plano_y saude_net_orig situacao
# marca_otica
# 78372767                GP3 - BLUE PLUS 500 QP        1697.25    ATIVO
# 291052304               GP3 - BLUE PLUS 300 QC        1846.20    ATIVO
# 291093370               GP3 - BLUE PLUS 300 QC        1984.11  INATIVO
# 291139507               GP3 - BLUE PLUS 500 QP        2910.02    ATIVO
# 291191630               GP3 - BLUE PLUS 500 QP        1893.57    ATIVO
# 291214061               GP3 - BLUE PLUS 300 QC        3586.30  INATIVO
# 291238688               GP3 - BLUE PLUS 300 QC        2182.44    ATIVO
# 291263194               GP3 - BLUE PLUS 400 QP        3898.29    ATIVO
# 291285783               GP3 - BLUE PLUS 600 QP        5197.56    ATIVO
# 291305148    GP4 - AMIL 700 NACIONAL R PJCA QP        3892.76    ATIVO
# 291441203    GP4 - AMIL 400 NACIONAL R PJCA QP        2834.42  INATIVO
# 291469272    GP4 - AMIL 400 NACIONAL R PJCA QP        8525.43    ATIVO
# 852199546               GP3 - BLUE PLUS 300 QP        1498.64    ATIVO
# 852308507               GP3 - BLUE PLUS 300 QP        1498.64    ATIVO
#
# [14 rows x 29 columns]

# %%
# Analisa quem é dependente
dependentes = []
for i in df_h_m_r.index:
    if df_h_m_r["tp_beneficiario"].at[i] == "D":
        dependentes.append(i)
print(f"qtd: {len(dependentes)}")
dependentes
# Out:
# qtd: 2
# [78372767, 852199546]

# %%
# Apenas uma amostra
counter = 0
divergencias = {"valor_orig", "val"}
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) != int(df_h_m_r["saude_net_orig"].at[i]):
        #if "Capita" in df_h_m_r["rubrica"].at[i]:
        if df_h_m_r["tp_beneficiario"].at[i] == "D":
            print("$"*30)
        counter += 1
        #print(df_h_m_r.loc[i])
        print(f"marca otica          - {i}")
        print(f"rubrica              - {df_h_m_r['rubrica'].at[i]}")
        print(f"tipo de beneficiario - {df_h_m_r['tp_beneficiario'].at[i]}")
        print(f"contrato             - {df_h_m_r['contrato'].at[i]}")
        #print(f"outros              - {df_h_m_r['outros'].at[i]}")
        print(f"valor orig           - {int(df_h_m_r['valor_orig'].at[i])}")
        print(f"saude net orig       - {int(df_h_m_r['saude_net_orig'].at[i])}")
        print(f"situacao             - {df_h_m_r['situacao'].at[i]}")
        print(f"cancelamento         - {df_h_m_r['dt_cancelamento'].at[i]}")
        print(f"competencia          - {df_h_m_r['competencia'].at[i]}")
        print("-"*30)
print(counter)
# Out:
# marca otica          - 291093370
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 192
# saude net orig       - 1984
# situacao             - INATIVO
# cancelamento         - 2022-07-28T21:00:00.000Z
# competencia          - 2022-08-04T21:00:00.000Z
# ------------------------------
# marca otica          - 291214061
# rubrica              - Devolução Exclusão Retroativa
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - -1388
# saude net orig       - 3586
# situacao             - INATIVO
# cancelamento         - 2022-07-17T21:00:00.000Z
# competencia          - 2022-08-04T21:00:00.000Z
# ------------------------------
# marca otica          - 291263194
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 4158
# saude net orig       - 3898
# situacao             - ATIVO
# cancelamento         - None
# competencia          - 2022-08-04T21:00:00.000Z
# ------------------------------
# marca otica          - 291285783
# rubrica              - Mens. Titular Faixa Etária Implant.
# tipo de beneficiario - T
# contrato             - 310572000
# valor orig           - 5198
# saude net orig       - 5197
# situacao             - ATIVO
# cancelamento         - None
# competencia          - 2022-08-04T21:00:00.000Z
# ------------------------------
# 4

# %%
# Identifica todos os casos conciliados e conciliados_com_div
bd = "cate"
matches = []
results = []
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) == int(df_h_m_r["saude_net_orig"].at[i]):
        #df_h_m_r.drop(i, inplace=True)
        matches.append(i)
        results.append("conciliado")
    elif df_h_m_r["valor_orig"].at[i] < 0 and "Retroativa" in df_h_m_r["rubrica"].at[i]:
        print(i)
        matches.append(i)
        results.append("conciliados")
    else:
        results.append("conciliados_com_div")
df_h_m_r["resultado"] = results
mongo_insert_many(df_h_m_r.to_dict("records"), db=bd, col="h_m_r_silver")
print(matches)
print(f"qtd: {len(matches)}")
# Out:
# 291214061
# [78372767, 291052304, 291139507, 291191630, 291214061, 291238688, 291305148, 291441203, 291469272, 852199546, 852308507]
# qtd: 11
