# %%
import pandas as pd
from mongo_portal import mongo_find_all, mongo_insert_one, mongo_insert_many

# Mostra as colunas e linhas da base header
header = mongo_find_all(db="cate", col="header_bronze")
df_header = pd.DataFrame(header)
print(f"linhas: {len(df_header.index)}")
df_header.head(5)
# Out:
# linhas: 100
#                         _id                   _idFile _lineNumber    contrato  \
# 0  6341ccb72174ddb0aa54a0ca  63223a45d28a2769c9bf447c           3   933510000
# 1  6341ccb72174ddb0aa54a0cb  63223a45ca86e8f62c58767e           3   722777000
# 2  6341ccb72174ddb0aa54a0cc  63223a45b1f53b82b7dc53a9           3   722771000
# 3  6341ccb72174ddb0aa54a0cd  63231c682d7ba147a2d2c108           3  1190478000
# 4  6341ccb72174ddb0aa54a0ce  63231c68a3c7ff58e05d22b7           3  1189426000
#
#              dt_competencia numero_fatura  \
# 0  2022-09-10T00:00:00.000Z      43708021
# 1  2022-09-10T00:00:00.000Z      43708018
# 2  2022-09-10T00:00:00.000Z      43708020
# 3  2022-09-15T00:00:00.000Z      43778802
# 4  2022-09-15T00:00:00.000Z      43762485
#
#                                               _idLog  \
# 0  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 1  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 2  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 3  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 4  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                    time_stamp
# 0  2022-10-08 16:16:49.472100
# 1  2022-10-08 16:16:49.472100
# 2  2022-10-08 16:16:49.472100
# 3  2022-10-08 16:16:49.472100
# 4  2022-10-08 16:16:49.472100

# %%
# Mostra os tipos de dados de cada coluna
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato          object
# dt_competencia    object
# numero_fatura     object
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Transforma o numero_fatura em número
df_header["numero_fatura"] = pd.to_numeric(df_header["numero_fatura"])
df_header.dtypes
# Out:
# _id               object
# _idFile           object
# _lineNumber       object
# contrato          object
# dt_competencia    object
# numero_fatura      int64
# _idLog            object
# time_stamp        object
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_header.isnull().sum()
# Out:
# _id               0
# _idFile           0
# _lineNumber       0
# contrato          0
# dt_competencia    0
# numero_fatura     0
# _idLog            0
# time_stamp        0
# dtype: int64

# %%
# Mostra as colunas e linhas da base mensalidade
mensalidade = mongo_find_all(db="cate", col="mensalidade_bronze")
df_mensalidade = pd.DataFrame(mensalidade)
print(f"linhas: {len(df_mensalidade.index)}")
df_mensalidade.head(5)
# Out:
# linhas: 587
#                         _id                   _idFile  \
# 0  63223b771ca5cd251fe8d49f  63223a45d28a2769c9bf447c
# 1  63223c5bd29a2b7ac1248cdb  63223a45ca86e8f62c58767e
# 2  63223d18ab12203e6b96324d  63223a45b1f53b82b7dc53a9
# 3  63223d18ab12203e6b96324e  63223a45b1f53b82b7dc53a9
# 4  63231d2eb0c53a35e66433d9  63231c682d7ba147a2d2c108
#
#            _idheader_bronze               dt_inclusao marca_otica  \
# 0  63223b771ca5cd251fe8d49e  2012-10-10T00:00:00.000Z   132729873
# 1  63223c5bd29a2b7ac1248cda  2010-07-20T00:00:00.000Z   132105896
# 2  63223d18ab12203e6b96324c  2012-09-20T00:00:00.000Z   132875764
# 3  63223d18ab12203e6b96324c  2012-09-20T00:00:00.000Z   132875764
# 4  63231d2eb0c53a35e66433d8  2019-04-01T00:00:00.000Z    75080003
#
#                              nome outros outros_orig  \
# 0               MXTX YDNX DW XNTW    0.0         0.0
# 1  VYTWNCX DY CXCX WXTY DY MYDYTW    0.0         0.0
# 2         TYJXNY DY MYDYTW TYXYTX    0.0         0.0
# 3         TYJXNY DY MYDYTW TYXYTX    0.0         0.0
# 4          PXULX MWTYTX DY WLVYTX    0.0         0.0
#
#                             plano                               rubrica  \
# 0                 MEDICUS QC - RN  Mens. Titular Faixa EtÃ¡ria Implant.
# 1  SAUDE QC - 21 C/OBST-PJ (CONV)  Mens. Titular Faixa EtÃ¡ria Implant.
# 2   MEDICUS QC 122 PARTICIP. - RN  Mens. Titular Faixa EtÃ¡ria Implant.
# 3   MEDICUS QC 122 PARTICIP. - RN                     Co-participaÃ§Ã£o
# 4     NEXT MUN SÃƒO PAULO QC PJCA  Mens. Titular Faixa EtÃ¡ria Implant.
#
#   tp_beneficiario valor_orig  \
# 0               T    2212.69
# 1               T     760.47
# 2               T    3439.81
# 3               T        0.0
# 4               T     664.46
#
#                                               _idLog  \
# 0  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 1  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 2  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 3  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 4  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                    time_stamp
# 0  2022-10-08 16:16:49.686099
# 1  2022-10-08 16:16:49.686099
# 2  2022-10-08 16:16:49.686099
# 3  2022-10-08 16:16:49.686099
# 4  2022-10-08 16:16:49.686099

# %%
df_mensalidade.dtypes
# Out:
# _id                 object
# _idFile             object
# _idheader_bronze    object
# dt_inclusao         object
# marca_otica         object
# nome                object
# outros              object
# outros_orig         object
# plano               object
# rubrica             object
# tp_beneficiario     object
# valor_orig          object
# _idLog              object
# time_stamp          object
# dtype: object

# %%
# Transforma algumas colunas em número
df_mensalidade["marca_otica"] = pd.to_numeric(df_mensalidade["marca_otica"])
df_mensalidade["valor_orig"] = pd.to_numeric(df_mensalidade["valor_orig"])
#df_mensalidade["outros"] = pd.to_numeric(df_mensalidade["outros"])
#df_mensalidade["outros_orig"] = pd.to_numeric(df_mensalidade["outros_orig"])
df_mensalidade.dtypes
# Out:
# _id                  object
# _idFile              object
# _idheader_bronze     object
# dt_inclusao          object
# marca_otica           int64
# nome                 object
# outros               object
# outros_orig          object
# plano                object
# rubrica              object
# tp_beneficiario      object
# valor_orig          float64
# _idLog               object
# time_stamp           object
# dtype: object

# %%
# Verifica se tem algum valor nulo
df_mensalidade.isnull().sum()
# Out:
# _id                 0
# _idFile             0
# _idheader_bronze    0
# dt_inclusao         0
# marca_otica         0
# nome                0
# outros              0
# outros_orig         0
# plano               0
# rubrica             0
# tp_beneficiario     0
# valor_orig          0
# _idLog              0
# time_stamp          0
# dtype: int64

# %%
# Une as duas bases usando o _idFile
df_header_mensalidade = pd.merge(df_header, df_mensalidade, on="_idFile")
print(f"linhas: {len(df_header_mensalidade.index)}")
df_header_mensalidade.isnull().sum()
# Out:
# linhas: 587
# _id_x               0
# _idFile             0
# _lineNumber         0
# contrato            0
# dt_competencia      0
# numero_fatura       0
# _idLog_x            0
# time_stamp_x        0
# _id_y               0
# _idheader_bronze    0
# dt_inclusao         0
# marca_otica         0
# nome                0
# outros              0
# outros_orig         0
# plano               0
# rubrica             0
# tp_beneficiario     0
# valor_orig          0
# _idLog_y            0
# time_stamp_y        0
# dtype: int64

# %%
# Mostra repetições
print(f"qtd de marca_otica contando repetições: {df_header_mensalidade['marca_otica'].value_counts().sum()}")
df_header_mensalidade["marca_otica"].value_counts()
# Out:
# qtd de marca_otica contando repetições: 587
# 73480119     9
# 73696271     6
# 73696273     6
# 73488684     4
# 82957528     3
#             ..
# 132105888    1
# 131935500    1
# 131887700    1
# 131870084    1
# 74090599     1
# Name: marca_otica, Length: 512, dtype: int64

# %%
# Transforma a marca_otica no index e remove suas repetições, deixando no mínimo 1 de cada
df_header_mensalidade_umarca = df_header_mensalidade.groupby("marca_otica").nth[0]
df_header_mensalidade_umarca.index.value_counts()
# Out:
# 73274996     1
# 73278611     1
# 83435393     1
# 83430634     1
# 83427893     1
#             ..
# 74870742     1
# 74870672     1
# 74870626     1
# 74870612     1
# 852308507    1
# Name: marca_otica, Length: 512, dtype: int64

# %%
# Mostra as colunas e qtd de linhas da base repasse
repasse = mongo_find_all(db="cate", col="repasse_bronze")
df_repasse = pd.DataFrame(repasse)
print(f"linhas: {len(df_repasse.index)}")
df_repasse.head(5)
# Out:
# linhas: 1585
#                         _id boleto_1 boleto_2 boleto_3 cod_contrato  \
# 0  6341cce12174ddb0aa54a130      SIM      SIM      SIM          nan
# 1  6341cce12174ddb0aa54a131      SIM      SIM      SIM          nan
# 2  6341cce12174ddb0aa54a132      SIM      SIM      SIM  927264000.0
# 3  6341cce12174ddb0aa54a133      SIM      SIM      SIM  927264000.0
# 4  6341cce12174ddb0aa54a134      SIM      SIM      SIM  927627000.0
#
#   codigo_convenio codigo_plano codigo_produto codigo_segurado  \
# 0             108           55              1           61745
# 1             108     26173391              1           61886
# 2             113     26609679              1           61922
# 3             113     26609673              1           61984
# 4             119     26650516              1           62011
#
#                 competencia  ... odonto_str operadora parcela_1  \
# 0  2022-08-20T00:00:00.000Z  ...        0.0      AMIL     122.0
# 1  2022-08-20T00:00:00.000Z  ...        0.0      AMIL     114.0
# 2  2022-08-20T00:00:00.000Z  ...        0.0      AMIL     110.0
# 3  2022-08-20T00:00:00.000Z  ...      40.22      AMIL     109.0
# 4  2022-08-20T00:00:00.000Z  ...        0.0      AMIL     108.0
#
#                                         plano    saude saude_net_orig  \
# 0  GL - SAUDE 50 QC - 21 - PJ (PARTICIPATIVO)   691.28          628.4
# 1                   GL - MEDMAIS SAÃšDE PJ QC   925.71         841.55
# 2                  GP1 - BLUE 400 NAC QP PJCA   2279.1        2028.44
# 3                  GP1 - BLUE 400 NAC QC PJCA  1156.22        2292.06
# 4                      GP2 - BLUE PLUS 400 QP  4364.94        3932.36
#
#   saude_orig situacao                                             _idLog  \
# 0     691.28    ATIVO  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 1     925.71  INATIVO  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 2     2279.1    ATIVO  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 3    1156.22  INATIVO  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 4    4364.94  INATIVO  2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                    time_stamp
# 0  2022-10-08 16:16:51.902062
# 1  2022-10-08 16:16:51.902062
# 2  2022-10-08 16:16:51.902062
# 3  2022-10-08 16:16:51.902062
# 4  2022-10-08 16:16:51.902062
#
# [5 rows x 36 columns]

# %%
df_repasse.dtypes
# Out:
# _id                   object
# boleto_1              object
# boleto_2              object
# boleto_3              object
# cod_contrato          object
# codigo_convenio       object
# codigo_plano          object
# codigo_produto        object
# codigo_segurado       object
# competencia           object
# convenio              object
# dependente            object
# dt_cancelamento       object
# dt_geracao            object
# dt_nascimento         object
# dt_situacao           object
# dt_suspensao          object
# inicio_vigencia       object
# marca_otica           object
# marca_otica_odonto    object
# nome                  object
# odonto                object
# odonto_net            object
# odonto_net_orig       object
# odonto_net_str        object
# odonto_orig           object
# odonto_str            object
# operadora             object
# parcela_1             object
# plano                 object
# saude                 object
# saude_net_orig        object
# saude_orig            object
# situacao              object
# _idLog                object
# time_stamp            object
# dtype: object

# %%
# Transforma algumas colunas em número
df_repasse["codigo_convenio"] = pd.to_numeric(df_repasse["codigo_convenio"])
df_repasse["codigo_plano"] = pd.to_numeric(df_repasse["codigo_plano"])
df_repasse["marca_otica"] = pd.to_numeric(df_repasse["marca_otica"])
#df_repasse["odonto"] = pd.to_numeric(df_repasse["odonto"])
#df_repasse["odonto_net"] = pd.to_numeric(df_repasse["odonto_net"])
#df_repasse["odonto_net_orig"] = pd.to_numeric(df_repasse["odonto_net_orig"])
#df_repasse["odonto_orig"] = pd.to_numeric(df_repasse["odonto_orig"])
df_repasse["saude_net_orig"] = pd.to_numeric(df_repasse["saude_net_orig"])
#df_repasse["saude_orig"] = pd.to_numeric(df_repasse["saude_orig"])
df_repasse["cod_contrato"] = df_repasse["cod_contrato"].astype(str)
df_repasse.dtypes
# Out:
# _id                    object
# boleto_1               object
# boleto_2               object
# boleto_3               object
# cod_contrato           object
# codigo_convenio         int64
# codigo_plano            int64
# codigo_produto         object
# codigo_segurado        object
# competencia            object
# convenio               object
# dependente             object
# dt_cancelamento        object
# dt_geracao             object
# dt_nascimento          object
# dt_situacao            object
# dt_suspensao           object
# inicio_vigencia        object
# marca_otica             int64
# marca_otica_odonto     object
# nome                   object
# odonto                 object
# odonto_net             object
# odonto_net_orig        object
# odonto_net_str         object
# odonto_orig            object
# odonto_str             object
# operadora              object
# parcela_1              object
# plano                  object
# saude                  object
# saude_net_orig        float64
# saude_orig             object
# situacao               object
# _idLog                 object
# time_stamp             object
# dtype: object

# %%
# Separa as linhas repetidas, mantendo pelo menos um registro das repetições
mask = df_repasse.marca_otica.duplicated()
print(f"Linhas repetidas: {len(df_repasse[mask])}")
print(f"Linhas únicas: {len(df_repasse[~mask])}")
df_repasse_u = df_repasse[~mask].copy()
# Out:
# Linhas repetidas: 1055
# Linhas únicas: 530

# %%
# Analisa a coluna de contrato
df_repasse_u["cod_contrato"].value_counts()
# Out:
# nan             340
# 1189455000.0     42
# 1189426000.0     20
# 1189449000.0     13
# 108739000.0      10
# 1191011000.0      8
# 0.0               8
# 1189435000.0      7
# 310572000.0       7
# 326288000.0       6
# 1191014000.0      5
# 318048000.0       5
# 927614000.0       5
# 1201671000.0      5
# 927627000.0       4
# 927632000.0       4
# 1189459000.0      4
# 1201881000.0      3
# 311084000.0       3
# 1189442000.0      3
# 927616000.0       3
# 108697000.0       3
# 927223000.0       2
# 336362000.0       2
# 938494000.0       2
# 927264000.0       2
# 1189445000.0      2
# 310453000.0       2
# 310603000.0       2
# 927630000.0       2
# 320087000.0       1
# 1190477000.0      1
# 326376000.0       1
# 310450000.0       1
# 15033000.0        1
# 1189029000.0      1
# Name: cod_contrato, dtype: int64

# %%
# Remove as linhas sem contrato ou com valor 0
bd = "silver_anomalies"
dados_insuficientes = df_repasse_u[df_repasse_u.cod_contrato == "nan"]
mongo_insert_many(dados_insuficientes.to_dict("records"), db=bd, col="dados_insuficientes")
dados_insuficientes = df_repasse_u[df_repasse_u.cod_contrato == "0.0"]
mongo_insert_many(dados_insuficientes.to_dict("records"), db=bd, col="dados_insuficientes")
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "nan"]
df_repasse_u = df_repasse_u[df_repasse_u.cod_contrato != "0.0"]
print(f"linhas: {len(df_repasse_u.index)}")
df_repasse_u["cod_contrato"].value_counts()
# Out:
# linhas: 182
# 1189455000.0    42
# 1189426000.0    20
# 1189449000.0    13
# 108739000.0     10
# 1191011000.0     8
# 1189435000.0     7
# 310572000.0      7
# 326288000.0      6
# 927614000.0      5
# 1201671000.0     5
# 318048000.0      5
# 1191014000.0     5
# 927627000.0      4
# 927632000.0      4
# 1189459000.0     4
# 927616000.0      3
# 108697000.0      3
# 311084000.0      3
# 1201881000.0     3
# 1189442000.0     3
# 927264000.0      2
# 938494000.0      2
# 336362000.0      2
# 927223000.0      2
# 1189445000.0     2
# 310453000.0      2
# 310603000.0      2
# 927630000.0      2
# 320087000.0      1
# 1190477000.0     1
# 326376000.0      1
# 310450000.0      1
# 15033000.0       1
# 1189029000.0     1
# Name: cod_contrato, dtype: int64

# %%
# Verifica se a marca_otica do repasse está presente no cruzamento header_mensalidade
counter = 0
marcas_match = []
for marca_repasse in df_repasse_u["marca_otica"]:
    if marca_repasse in df_header_mensalidade_umarca.index:    # marca_otica presente na header_mensalidade
        counter += 1
        marcas_match.append(marca_repasse)
    else:    # marca_otica ausente da header_mensalidade
        mongo_insert_one(df_repasse_u.query(f"marca_otica == {marca_repasse}").to_dict("records")[0], db=bd, col="somente_repasse" )
print(marcas_match)
print(f"qtd de marca_otica que deu match: {counter}")
# Out:
# [290440718, 290462797, 290568099, 290613159, 290750830, 290750857, 290750865, 290750849, 290839696, 290861713, 290963435, 851939406, 291146163, 291171680, 291171699, 291227023, 291296238, 291294006, 291350909, 291428789, 291515690, 291515703, 291515711, 291517307, 291151124, 84162731, 75018205, 290431174, 91320496, 290786762, 290791316, 290851130, 290870330, 291139507, 78372767, 291238688, 291285783, 291305148, 291441203, 291469272, 852199546, 852308507, 291191630, 73281320, 73274996, 73278611, 73375200, 73281314, 73471899, 82069302, 73478253, 73473269, 73478625, 73480119, 73473301, 73473302, 73496023, 73696271, 73696273, 73711007, 73711014, 73696390, 73696396, 73711293, 73961027, 73961028, 73916263, 73916001, 73926993, 73916024, 74196114, 74203744, 74203760, 74196131, 74196137, 74388865, 74386950, 74388928, 74386937, 74386956, 74660136, 74660139, 74640405, 74640406, 74639924, 74640409, 74870612, 74857427, 74870626, 74857255, 74870742, 74870743, 75080003, 76020193, 76578032, 76581960, 76581961, 76581404, 76581419]
# qtd de marca_otica que deu match: 99

# %%
# Deixa separado em um novo df apenas as linhas com marca_otica que deu match
match = df_repasse_u["marca_otica"].isin(marcas_match)
df_repasse_m = df_repasse_u.copy()[match]
df_repasse_m["marca_otica"].value_counts()
# Out:
# 290440718    1
# 74196137     1
# 74203760     1
# 74203744     1
# 74196114     1
#             ..
# 290791316    1
# 290786762    1
# 91320496     1
# 290431174    1
# 76581419     1
# Name: marca_otica, Length: 99, dtype: int64

# %%
# Verifica os cod_contrato que estão presentes na base header_mensalidade
counter = 0
contrato_unmatch = []
contrato_match = []
for contrato_repasse in df_repasse_m["cod_contrato"]:
    search = df_header_mensalidade[df_header_mensalidade["contrato"] == contrato_repasse[:-2]]
    if len(search.isnull().values) >= 1:
        counter += 1
        if contrato_repasse not in contrato_match:
            contrato_match.append(contrato_repasse)
    else:
        if contrato_repasse not in contrato_unmatch:
            contrato_unmatch.append(contrato_repasse)
            mongo_insert_many(df_repasse_m.query(f"cod_contrato == '{contrato_repasse}'").to_dict("records"), db=bd, col="somente_repasse")
print(contrato_unmatch)
print(f"qtd de match: {counter}")
# Out:
# ['1189435000.0', '1201881000.0']
# qtd de match: 93

# %%
# Separa em um df apenas os matches de contrato
match = df_repasse_m["cod_contrato"].isin(contrato_match)
df_repasse_f = df_repasse_m.copy()[match]
df_repasse_f["cod_contrato"]
# Out:
# 2       927264000.0
# 3       927264000.0
# 7       927630000.0
# 8       927627000.0
# 9       927632000.0
#            ...
# 420    1189449000.0
# 422    1189455000.0
# 423    1189455000.0
# 427    1189449000.0
# 429    1189449000.0
# Name: cod_contrato, Length: 93, dtype: object

# %%
# Une as base header_mensalidade com a repasse
df_repasse_umarca = df_repasse_f.groupby("marca_otica").nth(0)
df_h_m_r = pd.merge(df_header_mensalidade_umarca, df_repasse_umarca, on="marca_otica")
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 73274996     6341ccb72174ddb0aa54a0dc  63237f26184c01ae66c9f263           3
# 73278611     6341ccb72174ddb0aa54a0d3  63237f257af67ea94a2a472d           3
# 73281314     6341ccb72174ddb0aa54a0dc  63237f26184c01ae66c9f263           3
# 73281320     6341ccb72174ddb0aa54a0d6  63237f25fbaee0d44217486b           3
# 73375200     6341ccb72174ddb0aa54a0d7  63237f25e093364c28c215ec           3
# ...                               ...                       ...         ...
# 291515711    6341ccb72174ddb0aa54a0ff  632b9ee86ac6712ba8ba10b2           3
# 291517307    6341ccb72174ddb0aa54a0ff  632b9ee86ac6712ba8ba10b2           3
# 851939406    6341ccb72174ddb0aa54a102  632b9eebf4cc9c87c95ec90f           3
# 852199546    6341ccb72174ddb0aa54a0ea  63237f26be8b4f1285819dce           3
# 852308507    6341ccb72174ddb0aa54a0ea  63237f26be8b4f1285819dce           3
#
#                contrato            dt_competencia  numero_fatura  \
# marca_otica
# 73274996     1189455000  2022-09-15T00:00:00.000Z       43762154
# 73278611     1191014000  2022-09-15T00:00:00.000Z       43761551
# 73281314     1189455000  2022-09-15T00:00:00.000Z       43762154
# 73281320     1191011000  2022-09-15T00:00:00.000Z       43761669
# 73375200     1190477000  2022-09-15T00:00:00.000Z       43761917
# ...                 ...                       ...            ...
# 291515711     108739000  2022-09-30T00:00:00.000Z       44011581
# 291517307     108739000  2022-09-30T00:00:00.000Z       44011581
# 851939406     310450000  2022-09-30T00:00:00.000Z        1127100
# 852199546     311084000  2022-09-15T00:00:00.000Z        1119216
# 852308507     311084000  2022-09-15T00:00:00.000Z        1119216
#
#                                                       _idLog_x  \
# marca_otica
# 73274996     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73278611     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281314     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281320     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73375200     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# ...                                                        ...
# 291515711    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 291517307    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 851939406    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852199546    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852308507    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                            time_stamp_x                     _id_y  \
# marca_otica
# 73274996     2022-10-08 16:16:49.472100  6323887598f2c51958839e29
# 73278611     2022-10-08 16:16:49.472100  63238030258ce6039f97faa1
# 73281314     2022-10-08 16:16:49.472100  6323887598f2c51958839e2a
# 73281320     2022-10-08 16:16:49.472100  632382fa5885ea47e8ac259f
# 73375200     2022-10-08 16:16:49.472100  632383e84a9b0e4d2fd54c5c
# ...                                 ...                       ...
# 291515711    2022-10-08 16:16:49.472100  632ba02b80baf46c0f3bd403
# 291517307    2022-10-08 16:16:49.472100  632ba02b80baf46c0f3bd406
# 851939406    2022-10-08 16:16:49.472100  632ba2fe5b2e1314b2444547
# 852199546    2022-10-08 16:16:49.472100  632395a4776f10102c667397
# 852308507    2022-10-08 16:16:49.472100  632395a4776f10102c667398
#
#                      _idheader_bronze  ... odonto_str operadora parcela_1  \
# marca_otica                            ...
# 73274996     6323887598f2c51958839e28  ...        0.0      AMIL      48.0
# 73278611     63238030258ce6039f97faa0  ...        0.0      AMIL      48.0
# 73281314     6323887598f2c51958839e28  ...        0.0      AMIL      48.0
# 73281320     632382fa5885ea47e8ac259e  ...        0.0      AMIL      48.0
# 73375200     632383e74a9b0e4d2fd54c5b  ...        0.0      AMIL      48.0
# ...                               ...  ...        ...       ...       ...
# 291515711    632ba02b80baf46c0f3bd3fe  ...        0.0      AMIL      72.0
# 291517307    632ba02b80baf46c0f3bd3fe  ...        0.0      AMIL      72.0
# 851939406    632ba2fe5b2e1314b2444546  ...        0.0      AMIL      95.0
# 852199546    632395a3776f10102c667395  ...        0.0      AMIL      92.0
# 852308507    632395a3776f10102c667395  ...        0.0      AMIL      90.0
#
#                                               plano_y    saude saude_net_orig  \
# marca_otica
# 73274996                         AMIL 400 QC NACIONAL  1544.77        1297.66
# 73278611                  AMIL 400 QC NACIONAL COPART  1313.12        1103.02
# 73281314                         AMIL 400 QC NACIONAL  1235.86        1038.11
# 73281320                         AMIL 400 QP NACIONAL  3835.39        3221.73
# 73375200                         AMIL 400 QC NACIONAL  2124.11        1784.23
# ...                                               ...      ...            ...
# 291515711    GP4 - AMIL 400 NACIONAL R COPART PJCA QP  1371.42        1213.60
# 291517307    GP4 - AMIL 400 NACIONAL R COPART PJCA QC   3292.6        2913.83
# 851939406                      GP3 - BLUE PLUS 400 QC  3176.82        5094.46
# 852199546                      GP3 - BLUE PLUS 300 QP  1693.48        1498.64
# 852308507                      GP3 - BLUE PLUS 300 QP  1693.48        1498.64
#
#             saude_orig  situacao  \
# marca_otica
# 73274996       1544.77     ATIVO
# 73278611       1313.12     ATIVO
# 73281314       1235.86     ATIVO
# 73281320       3835.39   INATIVO
# 73375200       2124.11     ATIVO
# ...                ...       ...
# 291515711      1371.42     ATIVO
# 291517307       3292.6     ATIVO
# 851939406      3176.82     ATIVO
# 852199546      1693.48     ATIVO
# 852308507      1693.48     ATIVO
#
#                                                         _idLog  \
# marca_otica
# 73274996     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73278611     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281314     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281320     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73375200     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# ...                                                        ...
# 291515711    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 291517307    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 851939406    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852199546    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852308507    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                              time_stamp
# marca_otica
# 73274996     2022-10-08 16:16:51.902062
# 73278611     2022-10-08 16:16:51.902062
# 73281314     2022-10-08 16:16:51.902062
# 73281320     2022-10-08 16:16:51.902062
# 73375200     2022-10-08 16:16:51.902062
# ...                                 ...
# 291515711    2022-10-08 16:16:51.902062
# 291517307    2022-10-08 16:16:51.902062
# 851939406    2022-10-08 16:16:51.902062
# 852199546    2022-10-08 16:16:51.902062
# 852308507    2022-10-08 16:16:51.902062
#
# [93 rows x 55 columns]

# %%
# Verifica as linhas que estavam no header_mensalidade mas não estavam no repasse
counter = 0
marcas_lost = []
df = df_header_mensalidade_umarca.reset_index(level=0)
for i in df_header_mensalidade_umarca.index:
    if i not in df_h_m_r.index:
        mongo_insert_one(df.loc[counter].to_dict(), db=bd, col="somente_cliente")
        marcas_lost.append(i)
    counter +=1
print(marcas_lost)
print(f"qtd de linhas perdidas: {len(marcas_lost)}")
# Out:
# [73381251, 73381258, 73381272, 73381292, 73389095, 73389117, 73389206, 73391207, 73391747, 73392390, 73392391, 73394844, 73394930, 73394939, 73412061, 73422263, 73471899, 73473260, 73473261, 73488684, 73520194, 73599752, 73599770, 73599795, 73599803, 73599809, 73599828, 73611746, 73611750, 73611782, 73611796, 73611877, 73611883, 73611923, 73617743, 73620887, 73744736, 73799319, 73804178, 73804191, 73804426, 73805829, 73805851, 73811692, 73814641, 73814683, 73814685, 73818614, 73879464, 73879465, 73879466, 73891002, 73891003, 74065759, 74065772, 74065782, 74065788, 74065816, 74065872, 74065876, 74065877, 74065879, 74065884, 74065888, 74065889, 74065890, 74070979, 74071033, 74071034, 74071040, 74075133, 74081703, 74081819, 74081820, 74081822, 74090462, 74090463, 74090599, 74090737, 74090917, 74092018, 74100532, 74203772, 74224932, 74313928, 74313959, 74313992, 74314019, 74314044, 74314055, 74314061, 74314788, 74316493, 74316914, 74322318, 74325051, 74327975, 74348481, 74386936, 74445817, 74543366, 74543367, 74543375, 74543403, 74543404, 74543413, 74543416, 74546888, 74550734, 74578033, 74639924, 74766926, 74766938, 74766979, 74766980, 74766989, 74770467, 74773612, 74773677, 74857416, 74870672, 74870742, 74870743, 74953325, 74953347, 74953371, 74957623, 74958124, 75187990, 75188001, 75188169, 75188267, 75188701, 75195110, 76019932, 76020193, 76090754, 76090758, 76090759, 76091317, 76100906, 76222817, 76224042, 76290662, 76290909, 76290913, 76469686, 76469757, 76469808, 76578013, 76578021, 76662247, 76662261, 76662264, 76662266, 76662270, 76662271, 76662272, 76663468, 76663612, 76663637, 76663915, 76664219, 76664230, 77985796, 81330194, 81330196, 81346252, 81346460, 81346462, 81346463, 81346468, 81346474, 81346517, 81346552, 81346554, 81346557, 81346573, 81346577, 81346625, 81346635, 81346638, 81346646, 81346647, 81346651, 81346668, 81435576, 81435968, 81435970, 81435971, 81565821, 81571077, 81571079, 81571085, 81571086, 81571096, 81571097, 81571098, 81581791, 81581792, 81581794, 81582215, 81640493, 82069302, 82476023, 82476030, 82476039, 82480924, 82494538, 82494546, 82494583, 82494584, 82590007, 82590010, 82610692, 82610697, 82652340, 82674191, 82674192, 82701512, 82701513, 82701516, 82756834, 82756835, 82756836, 82756838, 82916970, 82916977, 82916979, 82916996, 82919875, 82957169, 82957229, 82957462, 82957493, 82957494, 82957528, 82957565, 82957580, 83097664, 83097801, 83097802, 83097805, 83099175, 83099176, 83099264, 83099425, 83099548, 83100405, 83101219, 83141168, 83141180, 83141183, 83141184, 83141185, 83141787, 83147478, 83253395, 83253403, 83253404, 83253436, 83253437, 83253454, 83253465, 83253466, 83253467, 83253474, 83253475, 83253492, 83253493, 83253505, 83253507, 83253514, 83255039, 83255509, 83261338, 83261339, 83261340, 83276201, 83323442, 83327077, 83327078, 83327084, 83427163, 83427164, 83427166, 83427170, 83427171, 83427172, 83427173, 83427175, 83427176, 83427177, 83427199, 83427885, 83427890, 83427893, 83430634, 83435393, 83435409, 83490364, 83490365, 83490366, 83583806, 83583819, 83583824, 83583825, 83583829, 83583832, 83583833, 83583834, 83583842, 83583850, 83583853, 83583855, 83583863, 83583870, 83583913, 83584143, 83584144, 83649089, 83649090, 83751134, 83751137, 83751138, 83751155, 83751158, 83751160, 83751183, 83751185, 83751187, 83751188, 83754758, 83754762, 83786535, 83792066, 83905326, 83905327, 83905346, 83962567, 83967045, 83967046, 83967047, 83967048, 84090571, 84111161, 84570169, 131870050, 131870076, 131870084, 131887700, 131935500, 132105888, 132105896, 132105918, 132105942, 132223716, 132298520, 132334453, 132338238, 132667754, 132729873, 132736586, 132736594, 132875764, 132891417, 132909073, 132948800, 133150011, 133150364, 133150526, 133168948, 134562852, 290413788, 290462800, 290510228, 290753392, 290753406, 290812380, 290836050, 290901219, 290908876, 290937353, 290951119, 290963974, 290985978, 291026931, 291111408, 291125085, 291139515, 291146171, 291171702, 291171710, 291173640, 291173659, 2 ...
# qtd de linhas perdidas: 419

# %%
# Analisa se o contrato da match, afinal eles são os campos chave entre header e repasse
# Salva num dict alguns dados relevantes sobre essa anomalia
contrato_unmatch = {"header_mensalidade": [], "repasse": [], "tp_beneficiario": [], "marca_otica": [], "rubrica": []}
for i in df_h_m_r.index:    # contrato vem do header_mensalidade e cod_contrato do repasse
    if df_h_m_r["contrato"].at[i] != df_h_m_r["cod_contrato"].at[i][:-2]:
        contrato_unmatch["header_mensalidade"].append(df_h_m_r["contrato"].at[i])
        contrato_unmatch["repasse"].append(df_h_m_r["cod_contrato"].at[i][:-2])
        contrato_unmatch["tp_beneficiario"].append(df_h_m_r["tp_beneficiario"].at[i])
        contrato_unmatch["marca_otica"].append(i)
        contrato_unmatch["rubrica"].append(df_h_m_r["rubrica"].at[i])
        mongo_insert_one(df_h_m_r.loc[i].to_dict(), db=bd, col="dados_inconsistentes")
        df_h_m_r.drop(i, inplace=True)
contrato_unmatch
# Out:
# {'header_mensalidade': ['1198444000',
#   '1190478000',
#   '1190478000',
#   '1190478000',
#   '1197781000',
#   '927278000'],
#  'repasse': ['1191014000',
#   '1189449000',
#   '1189449000',
#   '1189449000',
#   '1189445000',
#   '927264000'],
#  'tp_beneficiario': ['D', 'T', 'T', 'T', 'D', 'T'],
#  'marca_otica': [75018205, 75080003, 76581404, 76581419, 84162731, 290462797],
#  'rubrica': ['Mens. Depend. Faixa EtÃ¡ria Implant.',
#   'Mens. Titular Faixa EtÃ¡ria Implant.',
#   'Mens. Titular Faixa EtÃ¡ria Implant.',
#   'Mens. Titular Faixa EtÃ¡ria Implant.',
#   'Mens. Depend. Faixa EtÃ¡ria Implant.',
#   'Mens. Titular Faixa EtÃ¡ria Implant.']}

# %%
df_h_m_r
# Out:
#                                 _id_x                   _idFile _lineNumber  \
# marca_otica
# 73274996     6341ccb72174ddb0aa54a0dc  63237f26184c01ae66c9f263           3
# 73278611     6341ccb72174ddb0aa54a0d3  63237f257af67ea94a2a472d           3
# 73281314     6341ccb72174ddb0aa54a0dc  63237f26184c01ae66c9f263           3
# 73281320     6341ccb72174ddb0aa54a0d6  63237f25fbaee0d44217486b           3
# 73375200     6341ccb72174ddb0aa54a0d7  63237f25e093364c28c215ec           3
# ...                               ...                       ...         ...
# 291515711    6341ccb72174ddb0aa54a0ff  632b9ee86ac6712ba8ba10b2           3
# 291517307    6341ccb72174ddb0aa54a0ff  632b9ee86ac6712ba8ba10b2           3
# 851939406    6341ccb72174ddb0aa54a102  632b9eebf4cc9c87c95ec90f           3
# 852199546    6341ccb72174ddb0aa54a0ea  63237f26be8b4f1285819dce           3
# 852308507    6341ccb72174ddb0aa54a0ea  63237f26be8b4f1285819dce           3
#
#                contrato            dt_competencia  numero_fatura  \
# marca_otica
# 73274996     1189455000  2022-09-15T00:00:00.000Z       43762154
# 73278611     1191014000  2022-09-15T00:00:00.000Z       43761551
# 73281314     1189455000  2022-09-15T00:00:00.000Z       43762154
# 73281320     1191011000  2022-09-15T00:00:00.000Z       43761669
# 73375200     1190477000  2022-09-15T00:00:00.000Z       43761917
# ...                 ...                       ...            ...
# 291515711     108739000  2022-09-30T00:00:00.000Z       44011581
# 291517307     108739000  2022-09-30T00:00:00.000Z       44011581
# 851939406     310450000  2022-09-30T00:00:00.000Z        1127100
# 852199546     311084000  2022-09-15T00:00:00.000Z        1119216
# 852308507     311084000  2022-09-15T00:00:00.000Z        1119216
#
#                                                       _idLog_x  \
# marca_otica
# 73274996     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73278611     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281314     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281320     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73375200     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# ...                                                        ...
# 291515711    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 291517307    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 851939406    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852199546    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852308507    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                            time_stamp_x                     _id_y  \
# marca_otica
# 73274996     2022-10-08 16:16:49.472100  6323887598f2c51958839e29
# 73278611     2022-10-08 16:16:49.472100  63238030258ce6039f97faa1
# 73281314     2022-10-08 16:16:49.472100  6323887598f2c51958839e2a
# 73281320     2022-10-08 16:16:49.472100  632382fa5885ea47e8ac259f
# 73375200     2022-10-08 16:16:49.472100  632383e84a9b0e4d2fd54c5c
# ...                                 ...                       ...
# 291515711    2022-10-08 16:16:49.472100  632ba02b80baf46c0f3bd403
# 291517307    2022-10-08 16:16:49.472100  632ba02b80baf46c0f3bd406
# 851939406    2022-10-08 16:16:49.472100  632ba2fe5b2e1314b2444547
# 852199546    2022-10-08 16:16:49.472100  632395a4776f10102c667397
# 852308507    2022-10-08 16:16:49.472100  632395a4776f10102c667398
#
#                      _idheader_bronze  ... odonto_str operadora parcela_1  \
# marca_otica                            ...
# 73274996     6323887598f2c51958839e28  ...        0.0      AMIL      48.0
# 73278611     63238030258ce6039f97faa0  ...        0.0      AMIL      48.0
# 73281314     6323887598f2c51958839e28  ...        0.0      AMIL      48.0
# 73281320     632382fa5885ea47e8ac259e  ...        0.0      AMIL      48.0
# 73375200     632383e74a9b0e4d2fd54c5b  ...        0.0      AMIL      48.0
# ...                               ...  ...        ...       ...       ...
# 291515711    632ba02b80baf46c0f3bd3fe  ...        0.0      AMIL      72.0
# 291517307    632ba02b80baf46c0f3bd3fe  ...        0.0      AMIL      72.0
# 851939406    632ba2fe5b2e1314b2444546  ...        0.0      AMIL      95.0
# 852199546    632395a3776f10102c667395  ...        0.0      AMIL      92.0
# 852308507    632395a3776f10102c667395  ...        0.0      AMIL      90.0
#
#                                               plano_y    saude saude_net_orig  \
# marca_otica
# 73274996                         AMIL 400 QC NACIONAL  1544.77        1297.66
# 73278611                  AMIL 400 QC NACIONAL COPART  1313.12        1103.02
# 73281314                         AMIL 400 QC NACIONAL  1235.86        1038.11
# 73281320                         AMIL 400 QP NACIONAL  3835.39        3221.73
# 73375200                         AMIL 400 QC NACIONAL  2124.11        1784.23
# ...                                               ...      ...            ...
# 291515711    GP4 - AMIL 400 NACIONAL R COPART PJCA QP  1371.42        1213.60
# 291517307    GP4 - AMIL 400 NACIONAL R COPART PJCA QC   3292.6        2913.83
# 851939406                      GP3 - BLUE PLUS 400 QC  3176.82        5094.46
# 852199546                      GP3 - BLUE PLUS 300 QP  1693.48        1498.64
# 852308507                      GP3 - BLUE PLUS 300 QP  1693.48        1498.64
#
#             saude_orig  situacao  \
# marca_otica
# 73274996       1544.77     ATIVO
# 73278611       1313.12     ATIVO
# 73281314       1235.86     ATIVO
# 73281320       3835.39   INATIVO
# 73375200       2124.11     ATIVO
# ...                ...       ...
# 291515711      1371.42     ATIVO
# 291517307       3292.6     ATIVO
# 851939406      3176.82     ATIVO
# 852199546      1693.48     ATIVO
# 852308507      1693.48     ATIVO
#
#                                                         _idLog  \
# marca_otica
# 73274996     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73278611     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281314     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73281320     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 73375200     2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# ...                                                        ...
# 291515711    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 291517307    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 851939406    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852199546    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
# 852308507    2022-10-08_16-16-49.229099_c208dbb3-473d-11ed-...
#
#                              time_stamp
# marca_otica
# 73274996     2022-10-08 16:16:51.902062
# 73278611     2022-10-08 16:16:51.902062
# 73281314     2022-10-08 16:16:51.902062
# 73281320     2022-10-08 16:16:51.902062
# 73375200     2022-10-08 16:16:51.902062
# ...                                 ...
# 291515711    2022-10-08 16:16:51.902062
# 291517307    2022-10-08 16:16:51.902062
# 851939406    2022-10-08 16:16:51.902062
# 852199546    2022-10-08 16:16:51.902062
# 852308507    2022-10-08 16:16:51.902062
#
# [87 rows x 55 columns]

# %%
# Analisa quem é dependente
dependentes = []
for i in df_h_m_r.index:
    if df_h_m_r["tp_beneficiario"].at[i] == "D":
        dependentes.append(i)
print(f"qtd: {len(dependentes)}")
dependentes
# Out:
# qtd: 13
# [73473302,
#  73696273,
#  73961028,
#  74640406,
#  76581961,
#  78372767,
#  290750849,
#  290750857,
#  290750865,
#  291171699,
#  291515703,
#  291515711,
#  852199546]

# %%
# Apenas uma amostra
counter = 0
divergencias = {"valor_orig", "val"}
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) != int(df_h_m_r["saude_net_orig"].at[i]):
        #if "Capita" in df_h_m_r["rubrica"].at[i]:
        if df_h_m_r["tp_beneficiario"].at[i] == "D":
            print("$"*30)
        counter += 1
        #print(df_h_m_r.loc[i])
        print(f"marca otica          - {i}")
        print(f"rubrica              - {df_h_m_r['rubrica'].at[i]}")
        print(f"tipo de beneficiario - {df_h_m_r['tp_beneficiario'].at[i]}")
        print(f"contrato             - {df_h_m_r['contrato'].at[i]}")
        #print(f"outros              - {df_h_m_r['outros'].at[i]}")
        print(f"valor orig           - {int(df_h_m_r['valor_orig'].at[i])}")
        print(f"saude net orig       - {int(df_h_m_r['saude_net_orig'].at[i])}")
        print(f"situacao             - {df_h_m_r['situacao'].at[i]}")
        print(f"cancelamento         - {df_h_m_r['dt_cancelamento'].at[i]}")
        print(f"competencia          - {df_h_m_r['competencia'].at[i]}")
        print("-"*30)
print(counter)
# Out:
# marca otica          - 73473301
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 1189426000
# valor orig           - 3514
# saude net orig       - 2408
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# marca otica          - 73473302
# rubrica              - Mens. Depend. Faixa EtÃ¡ria Implant.
# tipo de beneficiario - D
# contrato             - 1189426000
# valor orig           - 1609
# saude net orig       - 1103
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 73696396
# rubrica              - DevoluÃ§Ã£o ExclusÃ£o Retroativa
# tipo de beneficiario - T
# contrato             - 1189455000
# valor orig           - -1899
# saude net orig       - 2212
# situacao             - INATIVO
# cancelamento         - 2022-08-04T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 73711293
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 1191011000
# valor orig           - 1623
# saude net orig       - 3514
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 73926993
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 1191011000
# valor orig           - 3200
# saude net orig       - 3542
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 73961027
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 1191011000
# valor orig           - 2953
# saude net orig       - 2925
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 74196114
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 1189426000
# valor orig           - 2005
# saude net orig       - 2833
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 74660139
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 1189426000
# valor orig           - 4324
# saude net orig       - 7047
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 74857255
# rubrica              - Co-participaÃ§Ã£o
# tipo de beneficiario - T
# contrato             - 1191014000
# valor orig           - 0
# saude net orig       - 1254
# situacao             - INATIVO
# cancelamento         - 2022-07-28T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 74870612
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 1189426000
# valor orig           - 1682
# saude net orig       - 3542
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 76581960
# rubrica              - DevoluÃ§Ã£o ExclusÃ£o Retroativa
# tipo de beneficiario - T
# contrato             - 1189455000
# valor orig           - -537
# saude net orig       - 2323
# situacao             - INATIVO
# cancelamento         - 2022-08-23T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# marca otica          - 76581961
# rubrica              - DevoluÃ§Ã£o ExclusÃ£o Retroativa
# tipo de beneficiario - D
# contrato             - 1189455000
# valor orig           - -511
# saude net orig       - 2212
# situacao             - INATIVO
# cancelamento         - 2022-08-23T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 91320496
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 938494000
# valor orig           - 2058
# saude net orig       - 1842
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 290431174
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 927223000
# valor orig           - 3180
# saude net orig       - 2830
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 290440718
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 927264000
# valor orig           - 2279
# saude net orig       - 2028
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 290568099
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 927630000
# valor orig           - 5044
# saude net orig       - 3157
# situacao             - INATIVO
# cancelamento         - 2022-05-13T00:00:00.000Z
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 290613159
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 927627000
# valor orig           - 2663
# saude net orig       - 6726
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 290750830
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 927632000
# valor orig           - 2868
# saude net orig       - 9609
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# marca otica          - 290750849
# rubrica              - Mens. Dependente Per Capita
# tipo de beneficiario - D
# contrato             - 927632000
# valor orig           - 1164
# saude net orig       - 2752
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# marca otica          - 290750857
# rubrica              - Mens. Dependente Per Capita
# tipo de beneficiario - D
# contrato             - 927632000
# valor orig           - 2294
# saude net orig       - 9609
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# marca otica          - 290750865
# rubrica              - Mens. Dependente Per Capita
# tipo de beneficiario - D
# contrato             - 927632000
# valor orig           - 1269
# saude net orig       - 3027
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 290791316
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 927614000
# valor orig           - 7693
# saude net orig       - 8968
# situacao             - INATIVO
# cancelamento         - 2022-07-19T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 290839696
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 927630000
# valor orig           - 3229
# saude net orig       - 3228
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 290851130
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 927616000
# valor orig           - 5653
# saude net orig       - 9609
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# marca otica          - 290861713
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 927627000
# valor orig           - 2224
# saude net orig       - 2825
# situacao             - SUSPENSÃƒO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291146163
# rubrica              - Mens. Titular Per Capita
# tipo de beneficiario - T
# contrato             - 310603000
# valor orig           - 1497
# saude net orig       - 2800
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291227023
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 326288000
# valor orig           - 2480
# saude net orig       - 1552
# situacao             - INATIVO
# cancelamento         - 2022-06-13T00:00:00.000Z
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291294006
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 326376000
# valor orig           - 1194
# saude net orig       - 2398
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291296238
# rubrica              - DevoluÃ§Ã£o ExclusÃ£o Retroativa
# tipo de beneficiario - T
# contrato             - 326288000
# valor orig           - -111
# saude net orig       - 1686
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291428789
# rubrica              - Mens. Titular Faixa EtÃ¡ria Implant.
# tipo de beneficiario - T
# contrato             - 108739000
# valor orig           - 2436
# saude net orig       - 4284
# situacao             - ATIVO
# cancelamento         - nan
# competencia          - 2022-08-20T00:00:00.000Z
# ------------------------------
# marca otica          - 291469272
# rubrica              - DevoluÃ§Ã£o ExclusÃ£o Retroativa
# tipo de beneficiario - T
# contrato             - 108697000
# valor orig           - -1407
# saude net orig       - 8525
# situacao             - INATIVO
# cancelamento         - 2022-08-25T00:00:00.000Z
# competencia          - 2022-09-05T00:00:00.000Z
# ------------------------------
# 31

# %%
# Identifica todos os casos conciliados e conciliados_com_div
bd = "cate"
matches = []
results = []
for i in df_h_m_r.index:
    if int(df_h_m_r["valor_orig"].at[i]) == int(df_h_m_r["saude_net_orig"].at[i]):
        #df_h_m_r.drop(i, inplace=True)
        matches.append(i)
        results.append("conciliado")
    elif df_h_m_r["valor_orig"].at[i] < 0 and "Retroativa" in df_h_m_r["rubrica"].at[i]:
        print(i)
        matches.append(i)
        results.append("conciliados")
    else:
        results.append("conciliados_com_div")
df_h_m_r["resultado"] = results
mongo_insert_many(df_h_m_r.to_dict("records"), db=bd, col="h_m_r_silver")
print(matches)
print(f"qtd: {len(matches)}")
# Out:
# 73696396
# 76581960
# 76581961
# 291296238
# 291469272
# [73274996, 73278611, 73281314, 73281320, 73375200, 73473269, 73478253, 73478625, 73480119, 73496023, 73696271, 73696273, 73696390, 73696396, 73711007, 73711014, 73916001, 73916024, 73916263, 73961028, 74196131, 74196137, 74203744, 74203760, 74386937, 74386950, 74386956, 74388865, 74388928, 74640405, 74640406, 74640409, 74660136, 74857427, 74870626, 76578032, 76581960, 76581961, 78372767, 290786762, 290870330, 290963435, 291139507, 291151124, 291171680, 291171699, 291191630, 291238688, 291285783, 291296238, 291305148, 291350909, 291441203, 291469272, 291515690, 291515703, 291515711, 291517307, 851939406, 852199546, 852308507]
# qtd: 61
